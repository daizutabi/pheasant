# %% [markdown]
# # Title
#
# Text1

# %%
def func(x):
    return 2 * x

# %% [markdown]
# Text2

# %%
func(1)
# Out:
# 2

# %%
func(2)
# Out:
# 4

# %%
func(3)
# Out:
# 6

# %%
func(4)
# Out:
# 8

# %% [markdown]
# Text3

# %%
print(1)
# Out:
# 1
